# %%
import torch

torch.manual_seed(0)

import time

from torchrl.envs import GymEnv, StepCounter, TransformedEnv

env = TransformedEnv(GymEnv("CartPole-v1"), StepCounter())
env.set_seed(0)

from tensordict.nn import TensorDictModule as Mod, TensorDictSequential as Seq
# Out:
# /opt/anaconda3/envs/torchrl/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.num_envs to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_envs` for environment variables or `env.get_wrapper_attr('num_envs')` that will search the reminding wrappers.
#   logger.warn(
# /opt/anaconda3/envs/torchrl/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.reward_space to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.reward_space` for environment variables or `env.get_wrapper_attr('reward_space')` that will search the reminding wrappers.
#   logger.warn(

# %%
from torchrl.modules import EGreedyModule, MLP, QValueModule

value_mlp = MLP(out_features=env.action_spec.shape[-1], num_cells=[64, 64])
value_net = Mod(value_mlp, in_keys=["observation"], out_keys=["action_value"])
policy = Seq(value_net, QValueModule(env.action_spec))
exploration_module = EGreedyModule(
    env.action_spec, annealing_num_steps=100_000, eps_init=0.5
)
policy_explore = Seq(policy, exploration_module)
# Out:
# /opt/anaconda3/envs/torchrl/lib/python3.10/site-packages/torch/nn/modules/lazy.py:181: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
from torchrl.collectors import SyncDataCollector
from torchrl.data import LazyTensorStorage, ReplayBuffer

init_rand_steps = 5000
frames_per_batch = 100
optim_steps = 10
collector = SyncDataCollector(
    env,
    policy,
    frames_per_batch=frames_per_batch,
    total_frames=-1,
    init_random_frames=init_rand_steps,
)
rb = ReplayBuffer(storage=LazyTensorStorage(100_000))

from torch.optim import Adam

# %%
from torchrl.objectives import DQNLoss, SoftUpdate

loss = DQNLoss(value_network=policy, action_space=env.action_spec, delay_value=True)
optim = Adam(loss.parameters(), lr=0.02)
updater = SoftUpdate(loss, eps=0.99)

# %%
from torchrl._utils import logger as torchrl_logger
from torchrl.record import CSVLogger, VideoRecorder

path = "./training_loop"
logger = CSVLogger(exp_name="dqn", log_dir=path, video_format="mp4")
video_recorder = VideoRecorder(logger, tag="video")
record_env = TransformedEnv(
    GymEnv("CartPole-v1", from_pixels=True, pixels_only=False), video_recorder
)
# Out:
# /opt/anaconda3/envs/torchrl/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.num_envs to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.num_envs` for environment variables or `env.get_wrapper_attr('num_envs')` that will search the reminding wrappers.
#   logger.warn(
# /opt/anaconda3/envs/torchrl/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.reward_space to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.reward_space` for environment variables or `env.get_wrapper_attr('reward_space')` that will search the reminding wrappers.
#   logger.warn(

# %%
total_count = 0
total_episodes = 0
t0 = time.time()
for i, data in enumerate(collector):
    # Write data in replay buffer
    rb.extend(data)
    max_length = rb[:]["next", "step_count"].max()
    if len(rb) > init_rand_steps:
        # Optim loop (we do several optim steps
        # per batch collected for efficiency)
        for _ in range(optim_steps):
            sample = rb.sample(128)
            loss_vals = loss(sample)
            loss_vals["loss"].backward()
            optim.step()
            optim.zero_grad()
            # Update exploration factor
            exploration_module.step(data.numel())
            # Update target params
            updater.step()
            if i % 10:
                torchrl_logger.info(f"Max num steps: {max_length}, rb length {len(rb)}")
            total_count += data.numel()
            total_episodes += data["next", "done"].sum()
    if max_length > 200:
        break

t1 = time.time()

torchrl_logger.info(
    f"solved after {total_count} steps, {total_episodes} episodes and in {t1-t0}s."
)
# Out:
# 2024-02-22 12:37:30,037 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-02-22 12:37:30,042 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-02-22 12:37:30,046 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-02-22 12:37:30,050 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-02-22 12:37:30,054 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-02-22 12:37:30,058 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-02-22 12:37:30,062 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-02-22 12:37:30,066 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-02-22 12:37:30,070 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-02-22 12:37:30,074 [torchrl][INFO] Max num steps: 100, rb length 5200
# 2024-02-22 12:37:30,102 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-02-22 12:37:30,107 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-02-22 12:37:30,113 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-02-22 12:37:30,118 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-02-22 12:37:30,122 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-02-22 12:37:30,127 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-02-22 12:37:30,131 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-02-22 12:37:30,136 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-02-22 12:37:30,141 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-02-22 12:37:30,145 [torchrl][INFO] Max num steps: 100, rb length 5300
# 2024-02-22 12:37:30,173 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-02-22 12:37:30,178 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-02-22 12:37:30,182 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-02-22 12:37:30,186 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-02-22 12:37:30,190 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-02-22 12:37:30,194 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-02-22 12:37:30,199 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-02-22 12:37:30,204 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-02-22 12:37:30,208 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-02-22 12:37:30,212 [torchrl][INFO] Max num steps: 100, rb length 5400
# 2024-02-22 12:37:30,239 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-02-22 12:37:30,244 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-02-22 12:37:30,248 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-02-22 12:37:30,252 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-02-22 12:37:30,256 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-02-22 12:37:30,262 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-02-22 12:37:30,266 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-02-22 12:37:30,270 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-02-22 12:37:30,275 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-02-22 12:37:30,279 [torchrl][INFO] Max num steps: 100, rb length 5500
# 2024-02-22 12:37:30,305 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-02-22 12:37:30,309 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-02-22 12:37:30,313 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-02-22 12:37:30,317 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-02-22 12:37:30,320 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-02-22 12:37:30,324 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-02-22 12:37:30,328 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-02-22 12:37:30,332 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-02-22 12:37:30,336 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-02-22 12:37:30,339 [torchrl][INFO] Max num steps: 100, rb length 5600
# 2024-02-22 12:37:30,365 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-02-22 12:37:30,369 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-02-22 12:37:30,373 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-02-22 12:37:30,377 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-02-22 12:37:30,382 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-02-22 12:37:30,386 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-02-22 12:37:30,390 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-02-22 12:37:30,394 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-02-22 12:37:30,398 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-02-22 12:37:30,403 [torchrl][INFO] Max num steps: 100, rb length 5700
# 2024-02-22 12:37:30,430 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-02-22 12:37:30,435 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-02-22 12:37:30,439 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-02-22 12:37:30,443 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-02-22 12:37:30,447 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-02-22 12:37:30,451 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-02-22 12:37:30,457 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-02-22 12:37:30,461 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-02-22 12:37:30,465 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-02-22 12:37:30,470 [torchrl][INFO] Max num steps: 100, rb length 5800
# 2024-02-22 12:37:30,498 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-02-22 12:37:30,503 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-02-22 12:37:30,507 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-02-22 12:37:30,512 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-02-22 12:37:30,516 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-02-22 12:37:30,520 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-02-22 12:37:30,524 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-02-22 12:37:30,530 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-02-22 12:37:30,534 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-02-22 12:37:30,538 [torchrl][INFO] Max num steps: 100, rb length 5900
# 2024-02-22 12:37:30,565 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-02-22 12:37:30,570 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-02-22 12:37:30,573 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-02-22 12:37:30,578 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-02-22 12:37:30,582 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-02-22 12:37:30,586 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-02-22 12:37:30,590 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-02-22 12:37:30,595 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-02-22 12:37:30,599 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-02-22 12:37:30,606 [torchrl][INFO] Max num steps: 100, rb length 6000
# 2024-02-22 12:37:30,688 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-02-22 12:37:30,693 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-02-22 12:37:30,696 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-02-22 12:37:30,701 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-02-22 12:37:30,705 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-02-22 12:37:30,709 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-02-22 12:37:30,713 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-02-22 12:37:30,717 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-02-22 12:37:30,721 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-02-22 12:37:30,724 [torchrl][INFO] Max num steps: 103, rb length 6200
# 2024-02-22 12:37:30,750 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-02-22 12:37:30,754 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-02-22 12:37:30,758 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-02-22 12:37:30,762 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-02-22 12:37:30,766 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-02-22 12:37:30,771 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-02-22 12:37:30,775 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-02-22 12:37:30,779 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-02-22 12:37:30,783 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-02-22 12:37:30,787 [torchrl][INFO] Max num steps: 174, rb length 6300
# 2024-02-22 12:37:30,813 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-02-22 12:37:30,817 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-02-22 12:37:30,822 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-02-22 12:37:30,826 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-02-22 12:37:30,831 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-02-22 12:37:30,834 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-02-22 12:37:30,838 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-02-22 12:37:30,843 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-02-22 12:37:30,847 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-02-22 12:37:30,851 [torchrl][INFO] Max num steps: 174, rb length 6400
# 2024-02-22 12:37:30,876 [torchrl][INFO] Max num steps: 174, rb length 6500
# 2024-02-22 12:37:30,881 [torchrl][INFO] Max num steps: 174, rb length 6500
# 2024-02-22 12:37:30,884 [torchrl][INFO] Max num steps: 174, rb length 6500
# 2024-02-22 12:37:30,888 [torchrl][INFO] Max num steps: 174, rb length 6500
# 2024-02-22 12:37:30,892 [torchrl][INFO] Max num steps: 174, rb length 6500
# 2024-02-22 12:37:30,897 [torchrl][INFO] Max num steps: 174, rb length 6500
# 2024-02-22 12:37:30,901 [torchrl][INFO] Max num steps: 174, rb length 6500
# 2024-02-22 12:37:30,906 [torchrl][INFO] Max num steps: 174, rb length 6500
# 2024-02-22 12:37:30,910 [torchrl][INFO] Max num steps: 174, rb length 6500
# 2024-02-22 12:37:30,914 [torchrl][INFO] Max num steps: 174, rb length 6500
# 2024-02-22 12:37:30,942 [torchrl][INFO] Max num steps: 174, rb length 6600
# 2024-02-22 12:37:30,946 [torchrl][INFO] Max num steps: 174, rb length 6600
# 2024-02-22 12:37:30,950 [torchrl][INFO] Max num steps: 174, rb length 6600
# 2024-02-22 12:37:30,955 [torchrl][INFO] Max num steps: 174, rb length 6600
# 2024-02-22 12:37:30,959 [torchrl][INFO] Max num steps: 174, rb length 6600
# 2024-02-22 12:37:30,964 [torchrl][INFO] Max num steps: 174, rb length 6600
# 2024-02-22 12:37:30,969 [torchrl][INFO] Max num steps: 174, rb length 6600
# 2024-02-22 12:37:30,973 [torchrl][INFO] Max num steps: 174, rb length 6600
# 2024-02-22 12:37:30,977 [torchrl][INFO] Max num steps: 174, rb length 6600
# 2024-02-22 12:37:30,981 [torchrl][INFO] Max num steps: 174, rb length 6600
# 2024-02-22 12:37:31,007 [torchrl][INFO] Max num steps: 174, rb length 6700
# 2024-02-22 12:37:31,011 [torchrl][INFO] Max num steps: 174, rb length 6700
# 2024-02-22 12:37:31,015 [torchrl][INFO] Max num steps: 174, rb length 6700
# 2024-02-22 12:37:31,019 [torchrl][INFO] Max num steps: 174, rb length 6700
# 2024-02-22 12:37:31,023 [torchrl][INFO] Max num steps: 174, rb length 6700
# 2024-02-22 12:37:31,027 [torchrl][INFO] Max num steps: 174, rb length 6700
# 2024-02-22 12:37:31,031 [torchrl][INFO] Max num steps: 174, rb length 6700
# 2024-02-22 12:37:31,035 [torchrl][INFO] Max num steps: 174, rb length 6700
# 2024-02-22 12:37:31,038 [torchrl][INFO] Max num steps: 174, rb length 6700
# 2024-02-22 12:37:31,043 [torchrl][INFO] Max num steps: 174, rb length 6700
# 2024-02-22 12:37:31,069 [torchrl][INFO] Max num steps: 174, rb length 6800
# 2024-02-22 12:37:31,073 [torchrl][INFO] Max num steps: 174, rb length 6800
# 2024-02-22 12:37:31,077 [torchrl][INFO] Max num steps: 174, rb length 6800
# 2024-02-22 12:37:31,081 [torchrl][INFO] Max num steps: 174, rb length 6800
# 2024-02-22 12:37:31,086 [torchrl][INFO] Max num steps: 174, rb length 6800
# 2024-02-22 12:37:31,090 [torchrl][INFO] Max num steps: 174, rb length 6800
# 2024-02-22 12:37:31,094 [torchrl][INFO] Max num steps: 174, rb length 6800
# 2024-02-22 12:37:31,098 [torchrl][INFO] Max num steps: 174, rb length 6800
# 2024-02-22 12:37:31,102 [torchrl][INFO] Max num steps: 174, rb length 6800
# 2024-02-22 12:37:31,106 [torchrl][INFO] Max num steps: 174, rb length 6800
# 2024-02-22 12:37:31,133 [torchrl][INFO] Max num steps: 174, rb length 6900
# 2024-02-22 12:37:31,137 [torchrl][INFO] Max num steps: 174, rb length 6900
# 2024-02-22 12:37:31,142 [torchrl][INFO] Max num steps: 174, rb length 6900
# 2024-02-22 12:37:31,147 [torchrl][INFO] Max num steps: 174, rb length 6900
# 2024-02-22 12:37:31,151 [torchrl][INFO] Max num steps: 174, rb length 6900
# 2024-02-22 12:37:31,156 [torchrl][INFO] Max num steps: 174, rb length 6900
# 2024-02-22 12:37:31,160 [torchrl][INFO] Max num steps: 174, rb length 6900
# 2024-02-22 12:37:31,164 [torchrl][INFO] Max num steps: 174, rb length 6900
# 2024-02-22 12:37:31,168 [torchrl][INFO] Max num steps: 174, rb length 6900
# 2024-02-22 12:37:31,172 [torchrl][INFO] Max num steps: 174, rb length 6900
# 2024-02-22 12:37:31,198 [torchrl][INFO] Max num steps: 174, rb length 7000
# 2024-02-22 12:37:31,202 [torchrl][INFO] Max num steps: 174, rb length 7000
# 2024-02-22 12:37:31,206 [torchrl][INFO] Max num steps: 174, rb length 7000
# 2024-02-22 12:37:31,210 [torchrl][INFO] Max num steps: 174, rb length 7000
# 2024-02-22 12:37:31,215 [torchrl][INFO] Max num steps: 174, rb length 7000
# 2024-02-22 12:37:31,219 [torchrl][INFO] Max num steps: 174, rb length 7000
# 2024-02-22 12:37:31,223 [torchrl][INFO] Max num steps: 174, rb length 7000
# 2024-02-22 12:37:31,227 [torchrl][INFO] Max num steps: 174, rb length 7000
# 2024-02-22 12:37:31,231 [torchrl][INFO] Max num steps: 174, rb length 7000
# 2024-02-22 12:37:31,234 [torchrl][INFO] Max num steps: 174, rb length 7000
# 2024-02-22 12:37:31,315 [torchrl][INFO] Max num steps: 174, rb length 7200
# 2024-02-22 12:37:31,319 [torchrl][INFO] Max num steps: 174, rb length 7200
# 2024-02-22 12:37:31,323 [torchrl][INFO] Max num steps: 174, rb length 7200
# 2024-02-22 12:37:31,328 [torchrl][INFO] Max num steps: 174, rb length 7200
# 2024-02-22 12:37:31,332 [torchrl][INFO] Max num steps: 174, rb length 7200
# 2024-02-22 12:37:31,336 [torchrl][INFO] Max num steps: 174, rb length 7200
# 2024-02-22 12:37:31,340 [torchrl][INFO] Max num steps: 174, rb length 7200
# 2024-02-22 12:37:31,344 [torchrl][INFO] Max num steps: 174, rb length 7200
# 2024-02-22 12:37:31,348 [torchrl][INFO] Max num steps: 174, rb length 7200
# 2024-02-22 12:37:31,352 [torchrl][INFO] Max num steps: 174, rb length 7200
# 2024-02-22 12:37:31,378 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-02-22 12:37:31,382 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-02-22 12:37:31,386 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-02-22 12:37:31,390 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-02-22 12:37:31,395 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-02-22 12:37:31,399 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-02-22 12:37:31,403 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-02-22 12:37:31,407 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-02-22 12:37:31,412 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-02-22 12:37:31,416 [torchrl][INFO] Max num steps: 194, rb length 7300
# 2024-02-22 12:37:31,443 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-02-22 12:37:31,447 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-02-22 12:37:31,452 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-02-22 12:37:31,457 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-02-22 12:37:31,461 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-02-22 12:37:31,465 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-02-22 12:37:31,471 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-02-22 12:37:31,475 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-02-22 12:37:31,480 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-02-22 12:37:31,485 [torchrl][INFO] Max num steps: 194, rb length 7400
# 2024-02-22 12:37:31,512 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-02-22 12:37:31,517 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-02-22 12:37:31,522 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-02-22 12:37:31,528 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-02-22 12:37:31,532 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-02-22 12:37:31,538 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-02-22 12:37:31,542 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-02-22 12:37:31,547 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-02-22 12:37:31,553 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-02-22 12:37:31,560 [torchrl][INFO] Max num steps: 194, rb length 7500
# 2024-02-22 12:37:31,587 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-02-22 12:37:31,592 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-02-22 12:37:31,596 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-02-22 12:37:31,600 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-02-22 12:37:31,605 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-02-22 12:37:31,609 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-02-22 12:37:31,613 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-02-22 12:37:31,616 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-02-22 12:37:31,621 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-02-22 12:37:31,625 [torchrl][INFO] Max num steps: 194, rb length 7600
# 2024-02-22 12:37:31,651 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-02-22 12:37:31,655 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-02-22 12:37:31,660 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-02-22 12:37:31,664 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-02-22 12:37:31,668 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-02-22 12:37:31,673 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-02-22 12:37:31,677 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-02-22 12:37:31,681 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-02-22 12:37:31,685 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-02-22 12:37:31,689 [torchrl][INFO] Max num steps: 194, rb length 7700
# 2024-02-22 12:37:31,715 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-02-22 12:37:31,719 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-02-22 12:37:31,723 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-02-22 12:37:31,726 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-02-22 12:37:31,730 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-02-22 12:37:31,735 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-02-22 12:37:31,739 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-02-22 12:37:31,743 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-02-22 12:37:31,747 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-02-22 12:37:31,751 [torchrl][INFO] Max num steps: 194, rb length 7800
# 2024-02-22 12:37:31,776 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-02-22 12:37:31,780 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-02-22 12:37:31,784 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-02-22 12:37:31,788 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-02-22 12:37:31,792 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-02-22 12:37:31,796 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-02-22 12:37:31,800 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-02-22 12:37:31,804 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-02-22 12:37:31,809 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-02-22 12:37:31,813 [torchrl][INFO] Max num steps: 194, rb length 7900
# 2024-02-22 12:37:31,839 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-02-22 12:37:31,843 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-02-22 12:37:31,847 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-02-22 12:37:31,851 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-02-22 12:37:31,855 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-02-22 12:37:31,859 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-02-22 12:37:31,864 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-02-22 12:37:31,868 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-02-22 12:37:31,874 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-02-22 12:37:31,878 [torchrl][INFO] Max num steps: 210, rb length 8000
# 2024-02-22 12:37:31,878 [torchrl][INFO] solved after 30000 steps, 1270 episodes and in 2.71914005279541s.

# %%
record_env.rollout(max_steps=3000, policy=policy)
video_recorder.dump()
